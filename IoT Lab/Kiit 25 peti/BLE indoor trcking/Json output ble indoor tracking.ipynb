# %% [markdown]
# # Trial number 1

# %%
import paho.mqtt.client as mqtt
import json

resp ={}
gateway_info = {}
gatewayid = []
macidsetlist = []
macidlist = []
rssilist = []
pckt = {}

# The callback for when the client receives a CONNECT response from the server.
def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected successfully")
    else:
        print("Connect returned result code: " + str(rc))

#The callback for when a PUBLISH message is received from the server.
def on_message(client, userdata, msg):
#     print("Received message: " + msg.topic + " -> " + msg.payload.decode("utf-8"))
    resp = json.loads(msg.payload.decode("utf-8"))
    formatting(resp)
    
def formatting(gateway1_resp):
    macidset = set()
    macid = []
    rssi = []
    gatewayid.append(gateway1_resp["id"])
    print("Gatewayid list {0}".format(gatewayid))
    beacon_data = gateway1_resp["raw_beacons_data"]
    beaconlist = beacon_data.split(";")
    rssi_dist = {'D1':0,'D0':3,'CF':6,'CE':9,'CD':12,'CC':15,'CB':18,'CA':21,'C9':24,'C8':27,'C7':30,'C6':33,'C5':36,'C4':39,'C3':42,'C2':45,'C1':48,'C0':51,'BF':54,'BE':57,'BD':60,'BC':63,'BB':66,'BA':69,'B9':72,'B8':75,'B7':78,'B6':81,'B5':84,'B4':87,'B3':90,'B2':93,'B1':96,'B0':99,'AF':102,'AE':105,'AD':108,'AC':111,'AB':114,'AA':117,'A9':120,'A8':123,'A7':126,'A6':129,'A5':129,'A4':132,'A3':135,'A2':138,'A1':141,'A0':144}
    for i in range(0,len(beaconlist)-1):
        payload = beaconlist[i]
        macidset.add(payload[:12])
        macid.append(payload[:12])
        rssi.append(payload[-2:])
    macidsetlist.append(macidset)
    macidlist.append(macid)
    rssilist.append(rssi)
    if(len(gatewayid) == 2):
        print("Gateway ID {}".format(gatewayid))
        print("MACID list {0}".format(macidlist))
        print("RSSI list {0}".format(rssilist))
        beacon_superset = list((set().union(*macidlist)))
        print("Beacon Sample space {0}".format(beacon_superset))
        for beaconnmbr in range(0,len(beacon_superset)):
            pckt["beacon"+str(beaconnmbr+1)] = {}
            pckt["beacon"+str(beaconnmbr+1)]["beacon_id"] = beacon_superset[beaconnmbr]
            pckt["beacon"+str(beaconnmbr+1)]["scanned_by"] = {}
            for gatewaynmbr in range(0,len(gatewayid)):
                pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)] = {}
                pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)]["gateway_id"] = gatewayid[gatewaynmbr]
                for beaconid in range(0,len(macidlist)):
        print("Ble Packet {0}".format(pckt))
        gatewayid.clear()
        macidlist.clear()
        rssilist.clear()
        macidsetlist.clear()
        print("*********************************************************************************")

# create the client
client = mqtt.Client()
client.on_connect = on_connect
client.on_message = on_message

# connect to HiveMQ Cloud on port 8883
client.connect("broker.hivemq.com", 1883)

# subscribe to the topic "my/test/topic"
client.subscribe([("/ufobeacons",0),("/ufobeacons1",0)])


# Blocking call that processes network traffic, dispatches callbacks and handles reconnecting.
client.loop_forever()

# %% [markdown]
# # Final JSON packet working script

# %%
import paho.mqtt.client as mqtt
import json

resp ={}
gateway_info = {}
gatewayid = []
macidsetlist = []
macidlist = []
rssilist = []
pckt = {}

# The callback for when the client receives a CONNECT response from the server.
def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected successfully")
    else:
        print("Connect returned result code: " + str(rc))

#The callback for when a PUBLISH message is received from the server.
def on_message(client, userdata, msg):
#     print("Received message: " + msg.topic + " -> " + msg.payload.decode("utf-8"))
    resp = json.loads(msg.payload.decode("utf-8"))
    formatting(resp)
    
def formatting(gateway1_resp):
    macidset = set()
    macid = []
    rssi = []
    gatewayid.append(gateway1_resp["id"])
#     print("Gatewayid list {0}".format(gatewayid))
    beacon_data = gateway1_resp["raw_beacons_data"]
    beaconlist = beacon_data.split(";")
    rssi_dist = {'E4':0,'E3':0,'E2':0,'E1':0,'E0':0,'DF':0,'DE':0,'DD':0,'DC':3,'DB':6,'DA':9,'D9':12,'D8':15,'D7':18,'D6':21,'D5':24,'D4':27,'D3':30,'D2':33,'D1':36,'D0':39,'CF':42,'CE':45,'CD':48,'CC':51,'CB':54,'CA':60,'C9':66,'C8':72,'C7':78,'C6':84,'C5':90,'C4':96,'C3':102,'C2':108,'C1':114,'C0':120,'BF':130,'BE':140,'BD':150,'BC':170,'BB':190,'BA':210,'B9':230,'B8':250,'B7':270,'B6':290,'B5':310,'B4':350,'B3':390,'B2':430,'B1':470,'B0':510,'AF':550,'AE':590,'AD':630,'AC':670,'AB':710,'AA':750,'A9':790,'A8':830,'A7':870,'A6':910,'A5':950,'A4':990,'A3':1030,'A2':1070,'A1':1110,'A0':1150}
    for i in range(0,len(beaconlist)-1):
        payload = beaconlist[i]
        macidset.add(payload[:12])
        macid.append(payload[:12])
        rssi.append(payload[-2:])
    macidsetlist.append(macidset)
    macidlist.append(macid)
    rssilist.append(rssi)
    if(len(gatewayid) == 2):
        print("Gateway ID {}".format(gatewayid))
        print("MACID list {0}".format(macidlist))
        print("RSSI list {0}".format(rssilist))
        beacon_superset = list((set().union(*macidlist)))
        print("Beacon Sample space {0}".format(beacon_superset))
        print("__________________________________________________")
        for beaconnmbr in range(0,len(beacon_superset)):
            pckt["beacon"+str(beaconnmbr+1)] = {}
            pckt["beacon"+str(beaconnmbr+1)]["beacon_id"] = beacon_superset[beaconnmbr]
            pckt["beacon"+str(beaconnmbr+1)]["scanned_by"] = {}
            for gatewaynmbr in range(0,len(gatewayid)): # Since the number of beacon macid responses is equal to the number of gateways
#                 print("gatewaynmbr: {0}".format(gatewaynmbr))
                pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)] = {}
                pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)]["gateway_id"] = gatewayid[gatewaynmbr]
                for beacons in range(0,len(macidlist[gatewaynmbr])):
#                     print("COMBOS: {0} , {1}".format(beacon_superset[beaconnmbr],macidlist[gatewaynmbr][beacons]))
                    if(beacon_superset[beaconnmbr] == macidlist[gatewaynmbr][beacons]):
#                         print("Common: {0} == {1}".format(beacon_superset[beaconnmbr],macidlist[gatewaynmbr][beacons]))
#                         print("Before gatewaynmbr : {0}, beacons: {1}".format(gatewaynmbr,beacons))
                        pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)]["rssi"] = rssilist[gatewaynmbr][beacons]
                        pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)]["dist"] = rssi_dist[rssilist[gatewaynmbr][beacons]]
                        print("Beacon{0} scanned by gateway{1} {2} with RSSI {3} and placed {4} cm away".format(beaconnmbr+1,gatewaynmbr+1,gatewayid[gatewaynmbr],rssilist[gatewaynmbr][beacons],rssi_dist[rssilist[gatewaynmbr][beacons]]))
                        break
                    else:
                        pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)]["rssi"] = "nan"
                        pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)]["dist"] = "nan"
#                         print("Beacon{0} not scanned by gateway{1} {2} as the RSSI is {3}".format(beaconnmbr+1,gatewaynmbr+1,gatewayid[gatewaynmbr],"nan"))
#                     print("Packet {0}".format(pckt))
        print("__________________________________________________")
        print("Ble Packet {0}".format(pckt))
        gatewayid.clear()
        macidlist.clear()
        rssilist.clear()
        macidsetlist.clear()
        beacon_superset.clear()
        pckt.clear()
        print("*********************************************************************************")

# create the client
client = mqtt.Client()
client.on_connect = on_connect
client.on_message = on_message

# connect to HiveMQ Cloud on port 8883
client.connect("broker.hivemq.com", 1883)

# subscribe to the topic "my/test/topic"
client.subscribe([("/ufobeacons",0),("/ufobeacons1",0)])


# Blocking call that processes network traffic, dispatches callbacks and handles reconnecting.
client.loop_forever()
# Out:
# Connected successfully
# Gateway ID ['F4844C4D4845', '28EC9A73BB1B']
# MACID list [['55464F61639D', '55464F604C56', '55464F6163A1', '55464FF34227'], ['55464F604C56', '55464FF34227']]
# RSSI list [['AF', 'C4', 'AF', 'B4'], ['BD', 'B5']]
# Beacon Sample space ['55464F604C56', '55464FF34227', '55464F61639D', '55464F6163A1']
# __________________________________________________
# Beacon1 scanned by gateway1 F4844C4D4845 with RSSI C4 and placed 96 cm away
# Beacon1 scanned by gateway2 28EC9A73BB1B with RSSI BD and placed 150 cm away
# Beacon2 scanned by gateway1 F4844C4D4845 with RSSI B4 and placed 350 cm away
# Beacon2 scanned by gateway2 28EC9A73BB1B with RSSI B5 and placed 310 cm away
# Beacon3 scanned by gateway1 F4844C4D4845 with RSSI AF and placed 550 cm away
# Beacon4 scanned by gateway1 F4844C4D4845 with RSSI AF and placed 550 cm away
# __________________________________________________
# Ble Packet {'beacon1': {'beacon_id': '55464F604C56', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'C4', 'dist': 96}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'BD', 'dist': 150}}}, 'beacon2': {'beacon_id': '55464FF34227', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'B4', 'dist': 350}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'B5', 'dist': 310}}}, 'beacon3': {'beacon_id': '55464F61639D', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'AF', 'dist': 550}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'nan', 'dist': 'nan'}}}, 'beacon4': {'beacon_id': '55464F6163A1', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'AF', 'dist': 550}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'nan', 'dist': 'nan'}}}}
# *********************************************************************************
# Gateway ID ['F4844C4D4845', '28EC9A73BB1B']
# MACID list [['55464FF34227'], ['55464F604C56', '55464FF34227']]
# RSSI list [['B5'], ['B7', 'B6']]
# Beacon Sample space ['55464F604C56', '55464FF34227']
# __________________________________________________
# Beacon1 scanned by gateway2 28EC9A73BB1B with RSSI B7 and placed 270 cm away
# Beacon2 scanned by gateway1 F4844C4D4845 with RSSI B5 and placed 310 cm away
# Beacon2 scanned by gateway2 28EC9A73BB1B with RSSI B6 and placed 290 cm away
# __________________________________________________
# Ble Packet {'beacon1': {'beacon_id': '55464F604C56', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'nan', 'dist': 'nan'}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'B7', 'dist': 270}}}, 'beacon2': {'beacon_id': '55464FF34227', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'B5', 'dist': 310}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'B6', 'dist': 290}}}}
# *********************************************************************************
# Gateway ID ['F4844C4D4845', '28EC9A73BB1B']
# MACID list [['55464F61639D', '55464F604C56', '55464F6163A1', '55464FF34227'], ['55464F604C56', '55464FF34227']]
# RSSI list [['AD', 'BD', 'AF', 'BB'], ['B7', 'B5']]
# Beacon Sample space ['55464F604C56', '55464FF34227', '55464F61639D', '55464F6163A1']
# __________________________________________________
# Beacon1 scanned by gateway1 F4844C4D4845 with RSSI BD and placed 150 cm away
# Beacon1 scanned by gateway2 28EC9A73BB1B with RSSI B7 and placed 270 cm away
# Beacon2 scanned by gateway1 F4844C4D4845 with RSSI BB and placed 190 cm away
# Beacon2 scanned by gateway2 28EC9A73BB1B with RSSI B5 and placed 310 cm away
# Beacon3 scanned by gateway1 F4844C4D4845 with RSSI AD and placed 630 cm away
# Beacon4 scanned by gateway1 F4844C4D4845 with RSSI AF and placed 550 cm away
# __________________________________________________
# Ble Packet {'beacon1': {'beacon_id': '55464F604C56', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'BD', 'dist': 150}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'B7', 'dist': 270}}}, 'beacon2': {'beacon_id': '55464FF34227', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'BB', 'dist': 190}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'B5', 'dist': 310}}}, 'beacon3': {'beacon_id': '55464F61639D', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'AD', 'dist': 630}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'nan', 'dist': 'nan'}}}, 'beacon4': {'beacon_id': '55464F6163A1', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'AF', 'dist': 550}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'nan', 'dist': 'nan'}}}}
# *********************************************************************************
# Gateway ID ['F4844C4D4845', '28EC9A73BB1B']
# MACID list [['55464F6163A1', '55464FF34227'], ['55464F604C56', '55464FF34227']]
# RSSI list [['AF', 'B2'], ['BC', 'B8']]
# Beacon Sample space ['55464F6163A1', '55464FF34227', '55464F604C56']
# __________________________________________________
# Beacon1 scanned by gateway1 F4844C4D4845 with RSSI AF and placed 550 cm away
# Beacon2 scanned by gateway1 F4844C4D4845 with RSSI B2 and placed 430 cm away
# Beacon2 scanned by gateway2 28EC9A73BB1B with RSSI B8 and placed 250 cm away
# Beacon3 scanned by gateway2 28EC9A73BB1B with RSSI BC and placed 170 cm away
# __________________________________________________
# Ble Packet {'beacon1': {'beacon_id': '55464F6163A1', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'AF', 'dist': 550}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'nan', 'dist': 'nan'}}}, 'beacon2': {'beacon_id': '55464FF34227', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'B2', 'dist': 430}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'B8', 'dist': 250}}}, 'beacon3': {'beacon_id': '55464F604C56', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'nan', 'dist': 'nan'}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'BC', 'dist': 170}}}}
# *********************************************************************************
# Gateway ID ['F4844C4D4845', '28EC9A73BB1B']
# MACID list [['55464F604C56', '55464FF34227'], ['55464FF34227']]
# RSSI list [['BE', 'BD'], ['B5']]
# Beacon Sample space ['55464F604C56', '55464FF34227']
# __________________________________________________
# Beacon1 scanned by gateway1 F4844C4D4845 with RSSI BE and placed 140 cm away
# Beacon2 scanned by gateway1 F4844C4D4845 with RSSI BD and placed 150 cm away
# Beacon2 scanned by gateway2 28EC9A73BB1B with RSSI B5 and placed 310 cm away
# __________________________________________________
# Ble Packet {'beacon1': {'beacon_id': '55464F604C56', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'BE', 'dist': 140}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'nan', 'dist': 'nan'}}}, 'beacon2': {'beacon_id': '55464FF34227', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'BD', 'dist': 150}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'B5', 'dist': 310}}}}
# *********************************************************************************
# Gateway ID ['F4844C4D4845', '28EC9A73BB1B']
# MACID list [['55464F61639D', '55464F604C56', '55464FF34227'], ['55464F604C56', '55464FF34227']]
# RSSI list [['AF', 'BD', 'B4'], ['BD', 'B5']]
# Beacon Sample space ['55464F604C56', '55464FF34227', '55464F61639D']
# __________________________________________________
# Beacon1 scanned by gateway1 F4844C4D4845 with RSSI BD and placed 150 cm away
# Beacon1 scanned by gateway2 28EC9A73BB1B with RSSI BD and placed 150 cm away
# Beacon2 scanned by gateway1 F4844C4D4845 with RSSI B4 and placed 350 cm away
# Beacon2 scanned by gateway2 28EC9A73BB1B with RSSI B5 and placed 310 cm away
# Beacon3 scanned by gateway1 F4844C4D4845 with RSSI AF and placed 550 cm away
# __________________________________________________
# Ble Packet {'beacon1': {'beacon_id': '55464F604C56', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'BD', 'dist': 150}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'BD', 'dist': 150}}}, 'beacon2': {'beacon_id': '55464FF34227', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'B4', 'dist': 350}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'B5', 'dist': 310}}}, 'beacon3': {'beacon_id': '55464F61639D', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'AF', 'dist': 550}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'nan', 'dist': 'nan'}}}}
# *********************************************************************************
# Gateway ID ['F4844C4D4845', '28EC9A73BB1B']
# MACID list [['55464F61639D', '55464F604C56', '55464F6163A1', '55464FF34227'], ['55464F604C56', '55464FF34227']]
# RSSI list [['AC', 'C3', 'AF', 'B2'], ['BB', 'B9']]
# Beacon Sample space ['55464F604C56', '55464FF34227', '55464F61639D', '55464F6163A1']
# __________________________________________________
# Beacon1 scanned by gateway1 F4844C4D4845 with RSSI C3 and placed 102 cm away
# Beacon1 scanned by gateway2 28EC9A73BB1B with RSSI BB and placed 190 cm away
# Beacon2 scanned by gateway1 F4844C4D4845 with RSSI B2 and placed 430 cm away
# Beacon2 scanned by gateway2 28EC9A73BB1B with RSSI B9 and placed 230 cm away
# Beacon3 scanned by gateway1 F4844C4D4845 with RSSI AC and placed 670 cm away
# Beacon4 scanned by gateway1 F4844C4D4845 with RSSI AF and placed 550 cm away
# __________________________________________________
# Ble Packet {'beacon1': {'beacon_id': '55464F604C56', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'C3', 'dist': 102}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'BB', 'dist': 190}}}, 'beacon2': {'beacon_id': '55464FF34227', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'B2', 'dist': 430}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'B9', 'dist': 230}}}, 'beacon3': {'beacon_id': '55464F61639D', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'AC', 'dist': 670}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'nan', 'dist': 'nan'}}}, 'beacon4': {'beacon_id': '55464F6163A1', 'scanned_by': {'gateway1': {'gateway_id': 'F4844C4D4845', 'rssi': 'AF', 'dist': 550}, 'gateway2': {'gateway_id': '28EC9A73BB1B', 'rssi': 'nan', 'dist': 'nan'}}}}
# *********************************************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8797797f59db> in <module>
#      92
#      93 # Blocking call that processes network traffic, dispatches callbacks and handles reconnecting.
# ---> 94 client.loop_forever()
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\paho\mqtt\client.py in loop_forever(self, timeout, max_packets, retry_first_connection)
#    1777             rc = MQTT_ERR_SUCCESS
#    1778             while rc == MQTT_ERR_SUCCESS:
# -> 1779                 rc = self.loop(timeout, max_packets)
#    1780                 # We don't need to worry about locking here, because we've
#    1781                 # either called loop_forever() when in single threaded mode, or
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\paho\mqtt\client.py in loop(self, timeout, max_packets)
#    1165         rlist = [self._sock, self._sockpairR]
#    1166         try:
# -> 1167             socklist = select.select(rlist, wlist, [], timeout)
#    1168         except TypeError:
#    1169             # Socket isn't correct type, in likelihood connection is lost
#
# KeyboardInterrupt:

# %% [markdown]
# # Union of set and dynamic string creation

# %%
list1 = [{'a','c','b'},{'a',5,6},{6,7}]
sample_space = list(set().union(*list1))
print(sample_space)
for i in range(0,len(sample_space)):
    print("beacon"+str(i))

# %% [markdown]
# # Trial number 2

# %%
import paho.mqtt.client as mqtt
import json

resp ={}
gateway_info = {}
gatewayid = []
macidsetlist = []
macidlist = []
rssilist = []
pckt = {}

# The callback for when the client receives a CONNECT response from the server.
def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected successfully")
    else:
        print("Connect returned result code: " + str(rc))

#The callback for when a PUBLISH message is received from the server.
def on_message(client, userdata, msg):
#     print("Received message: " + msg.topic + " -> " + msg.payload.decode("utf-8"))
    resp = json.loads(msg.payload.decode("utf-8"))
    formatting(resp)
    
def formatting(gateway1_resp):
    macidset = set()
    macid = []
    rssi = []
    gatewayid.append(gateway1_resp["id"])
#     print("Gatewayid list {0}".format(gatewayid))
    beacon_data = gateway1_resp["raw_beacons_data"]
    beaconlist = beacon_data.split(";")
    rssi_dist = {'D1':0,'D0':3,'CF':6,'CE':9,'CD':12,'CC':15,'CB':18,'CA':21,'C9':24,'C8':27,'C7':30,'C6':33,'C5':36,'C4':39,'C3':42,'C2':45,'C1':48,'C0':51,'BF':54,'BE':57,'BD':60,'BC':63,'BB':66,'BA':69,'B9':72,'B8':75,'B7':78,'B6':81,'B5':84,'B4':87,'B3':90,'B2':93,'B1':96,'B0':99,'AF':102,'AE':105,'AD':108,'AC':111,'AB':114,'AA':117,'A9':120,'A8':123,'A7':126,'A6':129,'A5':129,'A4':132,'A3':135,'A2':138,'A1':141,'A0':144}
    for i in range(0,len(beaconlist)-1):
        payload = beaconlist[i]
        macidset.add(payload[:12])
        macid.append(payload[:12])
        rssi.append(payload[-2:])
    macidsetlist.append(macidset)
    macidlist.append(macid)
    rssilist.append(rssi)
    if(len(gatewayid) == 2):
#         print("Gateway ID {}".format(gatewayid))
        print("MACID list {0}".format(macidlist))
        print("RSSI list {0}".format(rssilist))
        beacon_superset = list((set().union(*macidlist)))
        print("Beacon Sample space {0}".format(beacon_superset))
        for beaconnmbr in range(0,len(beacon_superset)):
            for gatewaynmbr in range(0,len(gatewayid)):
                for beacons in range(0,len(macidlist[gatewaynmbr])):
                    pckt["beacon"+str(beaconnmbr+1)] = {}
                    pckt["beacon"+str(beaconnmbr+1)]["beacon_id"] = beacon_superset[beaconnmbr]
                    pckt["beacon"+str(beaconnmbr+1)]["scanned_by"] = {}
                    print("gatewaynmbr: {0}".format(gatewaynmbr))
                    pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)] = {}
                    pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)]["gateway_id"] = gatewayid[gatewaynmbr]
#                         print("Common: {0} == {1}".format(beacon_superset[beaconnmbr],macidlist[gatewaynmbr][beacons]))
#                         print("Before gatewaynmbr : {0}, beacons: {1}".format(gatewaynmbr,beacons))
                    print("loop1: {0}, loop2: {1}, loop3: {2}".format(len(beacon_superset),len(gatewayid),len(macidlist[gatewaynmbr])))
                    print("Before combo gatewaynmbr : {0}, beacons: {1}, beaconmbr: {2}".format(gatewaynmbr,beacons,beaconnmbr))
#                     print("COMBOS: {0} , {1}".format(beacon_superset[beaconnmbr],macidlist[gatewaynmbr][beacons]))
                    if(beacon_superset[beaconnmbr] == macidlist[gatewaynmbr][beacons]):
                        pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)]["rssi"] = rssilist[gatewaynmbr][beacons]
                        if(beacons == len(macidlist[gatewaynmbr])-1):
                            break
                        elif(gatewaynmbr == len(gatewayid)-1):
                            break
                        else:
                            beacons == 0
                            gatewaynmbr+=1
                        print("After gatewaynmbr : {0}, beacons: {1}".format(gatewaynmbr,beacons))
                    else:
                        pckt["beacon"+str(beaconnmbr+1)]["scanned_by"]["gateway"+str(gatewaynmbr+1)]["rssi"] = "nan"
                    print("Packet {0}".format(pckt))
        print("Ble Packet {0}".format(pckt))
        gatewayid.clear()
        macidlist.clear()
        rssilist.clear()
        macidsetlist.clear()
        beacon_superset.clear()
        pckt.clear()
        print("*********************************************************************************")

# create the client
client = mqtt.Client()
client.on_connect = on_connect
client.on_message = on_message

# connect to HiveMQ Cloud on port 8883
client.connect("broker.hivemq.com", 1883)

# subscribe to the topic "my/test/topic"
client.subscribe([("/ufobeacons",0),("/ufobeacons1",0)])


# Blocking call that processes network traffic, dispatches callbacks and handles reconnecting.
client.loop_forever()

# %% [markdown]
# # Finding indices to access RSSI to enter the data in JSON

# %%
list1=[{'55464F604C56'}, {'55464F601993', '55464F604C56'}]
list2=['55464F601993', '55464F604C56']
list3=[{'AD'}, {'C7', 'BF'}]
for i in range(0,len(list1)):
    for j in range(0,len(list(list1[i]))):
        if(list2[i] in  list1[j]):
            print("macid {0} in gateway index {1} ".format(list2[i],i))
        else:
            print("macid {0} not in gateway index {1}".format(list2[i],i))

# %% [markdown]
# # Membership Test in sets

# %%
list1=[{'55464F604C56'}, {'55464F601993', '55464F604C56'}]
list2=['55464F601993', '55464F604C56']
list3=[['AD'], ['C7', 'BF']]
for i in range(0,len(list2)):
    for j in range(0,len(list1)):
        if(list2[i] in list1[j]):  #Membership Tests in sets
            print("macid {0} in gateway index {1}".format(list2[i],i))
        else:
            print("macid {0} not in gateway index {1}".format(list2[i],i))
